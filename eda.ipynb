# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df1=pd.read_csv("eda2.csv")

# %%
df1
# Out:
#     productCode                          productName  sum_priceeach  \
# 0      S18_1749             1917 Grand Touring Sedan        3842.00
# 1      S18_2248                   1911 Ford Town Car        1357.32
# 2      S18_4409  1932 Alfa Romeo 8C2300 Spider Sport        2074.40
# 3      S24_3969     1936 Mercedes Benz 500k Roadster         909.69
# 4      S18_2325            1932 Model A Ford J-Coupe        3198.61
# ..          ...                                  ...            ...
# 104    S24_1628            1966 Shelby Cobra 427 S/C        1143.05
# 105    S24_2766                   1949 Jaguar XK 120        2018.21
# 106    S24_2887                    1952 Citroen-15CV        2591.89
# 107    S24_3191            1969 Chevrolet Camaro Z28        1932.20
# 108    S24_3432                  2002 Chevy Corvette        2440.37
#
#      sum_buyprice  number_sales  total_price
# 0         2167.50           918       140536
# 1          832.50           832        45307
# ...

# %%
'''plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(df1.corr(), dtype=np.bool))
heatmap = sns.heatmap(df1.corr(), mask=mask,  annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=16)'''
# Out:
# "plt.figure(figsize=(16, 6))\nmask = np.triu(np.ones_like(df1.corr(), dtype=np.bool))\nheatmap = sns.heatmap(df1.corr(), mask=mask,  annot=True, cmap='BrBG')\nheatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18},\xa0pad=16)"

# %%
sns.histplot(x="number_sales",data=df1);

# %%
plt.bar(df1["productCode"].head(15),df1["number_sales"].head(15));
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=df1["sum_priceeach"].head(20),y=df1["sum_buyprice"].head(20),data=df1);

# %%
df1.plot.line(y=['sum_priceeach', 'sum_buyprice'], figsize=(10,6));

# %%
df1["sum_priceeach"].corr(df1["sum_buyprice"])
# Out:
# 0.9302485158964614

# %%
df2=pd.read_csv("eda3.csv")

# %%
df2
# Out:
#   Continent  total_customers
# 0    Europe               60
# 1       USA               36
# 2    Others               26

# %%
plt.pie(df2['total_customers'], labels=df2['Continent'], autopct='%1.1f%%');

# %%
sns.lmplot(x='number_sales', y='sum_priceeach', data=df1);

# %%
df3=pd.read_csv("eda4.csv")

# %%
df3
# Out:
#         country  number_sales
# 0           USA         35844
# 1         Spain         12429
# 2        France         11090
# 3     Australia          6246
# 4   New Zealand          5396
# 5            UK          5013
# 6         Italy          4045
# 7       Finland          3192
# 8        Norway          2842
# 9     Singapore          2760
# 10       Canada          2293
# 11      Denmark          2197
# 12      Germany          2148
# 13       Sweden          2006
# 14      Austria          1974
# 15        Japan          1842
# 16  Switzerland          1078
# 17      Belgium          1074
# 18  Philippines           961
# 19    Hong Kong           596
# 20      Ireland           490

# %%
plt.bar(df3["country"],df3["number_sales"]);
plt.xticks(rotation=90)
plt.show()
